# %% [markdown]
# <a href="https://colab.research.google.com/github/Alishakc02/ipynb/blob/main/Poissons_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# The Poisson distribution is a discrete probability distribution that expresses the probability of a given number of events occurring in a fixed interval of time or space, when the events happen independently and the average rate (λ) of occurrence is constant.
#
#
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
#Import libraries
from scipy.stats import poisson

# %%
#Calculation
mean=6
x=range(1,20)
#Formula
poiss_value=poisson.pmf(x,mean)
#Print the value
for i in x:
  print("P(X={})={}".format(i,poiss_value[i-1]))
# Out:
# P(X=1)=0.014872513059998144
# P(X=2)=0.04461753917999444
# P(X=3)=0.08923507835998894
# P(X=4)=0.13385261753998332
# P(X=5)=0.16062314104797995
# P(X=6)=0.1606231410479801
# P(X=7)=0.1376769780411257
# P(X=8)=0.1032577335308442
# P(X=9)=0.06883848902056285
# P(X=10)=0.04130309341233764
# P(X=11)=0.022528960043093245
# P(X=12)=0.011264480021546681
# P(X=13)=0.005198990779175391
# P(X=14)=0.0022281389053608724
# P(X=15)=0.0008912555621443482
# P(X=16)=0.00033422083580413026
# P(X=17)=0.00011796029498969308
# P(X=18)=3.932009832989778e-05
# P(X=19)=1.2416873156809801e-05

# %%
#Plot the bargraph
plt.figure(figsize=(12,8))
plt.bar(x,poiss_value, color='darkcyan')
plt.xlabel("X")
plt.ylabel("P(X)")
plt.title("Poisson Distribution")
plt.grid(True)
plt.tight_layout()
plt.show()
