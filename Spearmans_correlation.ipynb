# %% [markdown]
# <a href="https://colab.research.google.com/github/Alishakc02/ipynb/blob/main/Spearmans_correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# It measures the strength and direction of the monotonic (not necessarily linear) relationship between two variables using ranks rather than raw data.
# ```

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from scipy.stats import spearmanr

# %%
#Load the dataset
weight=[3.63,
3.02,
3.82,
3.42,
3.59,
2.87,
3.03,
3.46,
3.36,
3.3]

length=[	53.1, 49.7, 48.4, 54.2, 54.9, 43.7, 47.2, 45.2, 54.4, 50.4]

# %%
#Calculate the coefficient
rho, p_value =spearmanr(weight, length)
print(f"Spearman's rho:{rho}")
print(f"P-value :{p_value}")
# Out:
# Spearman's rho:0.38181818181818183
# P-value :0.27625533338543595

# %% [markdown]
# ```
# ρ=+1: perfect positive monotonic relationship
#
# ρ=-1: perfect negative monotonic relationship
#
# ρ=0: no correlation
# ```

# %%
#Second example
X=[7,6,4,5,8,7,10,3,9,2]
Y=[5,4,5,6,10,7,9,2,8,1]
rho, p_value=spearmanr(X,Y)
print(f"Spearman's rho:{rho}")
print(f"P-value :{p_value}")
# Out:
# Spearman's rho:0.875
# P-value :0.0009160935878753664

# %%
#Line graph to visualize
plt.plot(X,Y)
plt.title('Line graph')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
