# %% [markdown]
# <a href="https://colab.research.google.com/github/Alishakc02/ipynb/blob/main/Binomial_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ```
# The Binomial Distribution is a type of discrete probability distribution that models the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes — success or failure.
#
# Conditions for Binomial Distribution:
#
# The number of trials, n, is fixed.
# Each trial has only two outcomes: success (usually denoted as 1) or failure (denoted as 0).
# The probability of success, p, remains constant for every trial.
# All trials are independent of each other.
#
# ```

# %%
#Calculation
from scipy.stats import binom
n=20
p=0.4
x=range(n+1)

# %%
#Formula
binom_prob=binom.pmf(x,n,p)

for i in x:
  print(f"P(X={i})={binom_prob[i]:.4f}")
# Out:
# P(X=0)=0.0000
# P(X=1)=0.0005
# P(X=2)=0.0031
# P(X=3)=0.0123
# P(X=4)=0.0350
# P(X=5)=0.0746
# P(X=6)=0.1244
# P(X=7)=0.1659
# P(X=8)=0.1797
# P(X=9)=0.1597
# P(X=10)=0.1171
# P(X=11)=0.0710
# P(X=12)=0.0355
# P(X=13)=0.0146
# P(X=14)=0.0049
# P(X=15)=0.0013
# P(X=16)=0.0003
# P(X=17)=0.0000
# P(X=18)=0.0000
# P(X=19)=0.0000
# P(X=20)=0.0000

# %%
#Plot the data
plt.figure(figsize=(12,8))
plt.bar(x,binom_prob, color='darkcyan')
plt.xlabel("X")
plt.ylabel("Probability")
plt.title("Binomial Distribution")

plt.grid(True)
plt.tight_layout()
plt.show()
